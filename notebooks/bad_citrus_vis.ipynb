# %%
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame.from_dict([
  {
      "Architecture": "DenseNet",
      "Same Architecture Fraction": 1.0,
      "Metric": "Cosine"
  },
  {
      "Architecture": "DenseNet",
      "Same Architecture Fraction": 0.667,
      "Metric": "L-Infinity"
  },
  {
      "Architecture": "ResNet",
      "Same Architecture Fraction": 0.667,
      "Metric": "Cosine"
  },
  {
      "Architecture": "ResNet",
      "Same Architecture Fraction": 0.0,
      "Metric": "L-Infinity"
  },
  {
      "Architecture": "VGG",
      "Same Architecture Fraction": 1.0,
      "Metric": "Cosine"
  },
  {
      "Architecture": "VGG",
      "Same Architecture Fraction": 0.75,
      "Metric": "L-Infinity"
  },
])

# %%
sns.set_style("white")
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

ax = sns.barplot(data=df, x="Architecture", y="Same Architecture Fraction", hue="Metric", palette="Set2")
for i in ax.containers:
    ax.bar_label(i,)
ax.set_title("Closest Model According to Metric")
sns.despine()
plt.savefig('Archs.png')
plt.show()

# %%
dists = [
    {
        "Metric": "L-Infinity",
        "Target": "densenet121",
        "densenet121": "0.0",
        "densenet161": "2.526",
        "densenet169": "4.596",
        "googlenet": "3.663",
        "inception_v3": "3.567",
        "mobilenet_v2": "2.865",
        "resnet18": "3.143",
        "resnet34": "2.565",
        "resnet50": "2.910",
        "vgg11_bn": "4.058",
        "vgg13_bn": "3.552",
        "vgg16_bn": "3.837",
        "vgg19_bn": "5.815"
    },
    {
        "Metric": "L-Infinity",
        "Target": "densenet161",
        "densenet121": "2.526",
        "densenet161": "0.0",
        "densenet169": "2.478",
        "googlenet": "4.076",
        "inception_v3": "3.728",
        "mobilenet_v2": "3.231",
        "resnet18": "3.022",
        "resnet34": "3.680",
        "resnet50": "3.064",
        "vgg11_bn": "3.674",
        "vgg13_bn": "3.513",
        "vgg16_bn": "4.184",
        "vgg19_bn": "5.868"
    },
    {
        "Metric": "L-Infinity",
        "Target": "densenet169",
        "densenet121": "4.596",
        "densenet161": "2.478",
        "densenet169": "0.0",
        "googlenet": "4.291",
        "inception_v3": "3.475",
        "mobilenet_v2": "4.146",
        "resnet18": "2.669",
        "resnet34": "2.961",
        "resnet50": "2.404",
        "vgg11_bn": "3.806",
        "vgg13_bn": "3.818",
        "vgg16_bn": "4.733",
        "vgg19_bn": "5.567"
    },
    {
        "Metric": "L-Infinity",
        "Target": "googlenet",
        "densenet121": "3.663",
        "densenet161": "4.076",
        "densenet169": "4.291",
        "googlenet": "0.0",
        "inception_v3": "3.658",
        "mobilenet_v2": "3.607",
        "resnet18": "5.145",
        "resnet34": "4.868",
        "resnet50": "3.763",
        "vgg11_bn": "4.266",
        "vgg13_bn": "3.565",
        "vgg16_bn": "3.946",
        "vgg19_bn": "5.478"
    },
    {
        "Metric": "L-Infinity",
        "Target": "inception_v3",
        "densenet121": "3.567",
        "densenet161": "3.728",
        "densenet169": "3.475",
        "googlenet": "3.658",
        "inception_v3": "0.0",
        "mobilenet_v2": "3.299",
        "resnet18": "3.438",
        "resnet34": "3.506",
        "resnet50": "2.759",
        "vgg11_bn": "2.916",
        "vgg13_bn": "3.484",
        "vgg16_bn": "3.705",
        "vgg19_bn": "5.038"
    },
    {
        "Metric": "L-Infinity",
        "Target": "mobilenet_v2",
        "densenet121": "2.865",
        "densenet161": "3.231",
        "densenet169": "4.146",
        "googlenet": "3.607",
        "inception_v3": "3.299",
        "mobilenet_v2": "0.0",
        "resnet18": "3.681",
        "resnet34": "3.497",
        "resnet50": "2.602",
        "vgg11_bn": "3.312",
        "vgg13_bn": "3.504",
        "vgg16_bn": "4.030",
        "vgg19_bn": "5.286"
    },
    {
        "Metric": "L-Infinity",
        "Target": "resnet18",
        "densenet121": "3.143",
        "densenet161": "3.022",
        "densenet169": "2.669",
        "googlenet": "5.145",
        "inception_v3": "3.438",
        "mobilenet_v2": "3.681",
        "resnet18": "0.0",
        "resnet34": "2.890",
        "resnet50": "2.866",
        "vgg11_bn": "3.453",
        "vgg13_bn": "3.476",
        "vgg16_bn": "3.766",
        "vgg19_bn": "5.601"
    },
    {
        "Metric": "L-Infinity",
        "Target": "resnet34",
        "densenet121": "2.565",
        "densenet161": "3.680",
        "densenet169": "2.961",
        "googlenet": "4.868",
        "inception_v3": "3.506",
        "mobilenet_v2": "3.497",
        "resnet18": "2.890",
        "resnet34": "0.0",
        "resnet50": "3.356",
        "vgg11_bn": "3.519",
        "vgg13_bn": "3.403",
        "vgg16_bn": "3.243",
        "vgg19_bn": "5.312"
    },
    {
        "Metric": "L-Infinity",
        "Target": "resnet50",
        "densenet121": "2.910",
        "densenet161": "3.064",
        "densenet169": "2.404",
        "googlenet": "3.763",
        "inception_v3": "2.759",
        "mobilenet_v2": "2.602",
        "resnet18": "2.866",
        "resnet34": "3.356",
        "resnet50": "0.0",
        "vgg11_bn": "3.320",
        "vgg13_bn": "3.383",
        "vgg16_bn": "3.613",
        "vgg19_bn": "4.863"
    },
    {
        "Metric": "L-Infinity",
        "Target": "vgg11_bn",
        "densenet121": "4.058",
        "densenet161": "3.674",
        "densenet169": "3.806",
        "googlenet": "4.266",
        "inception_v3": "2.916",
        "mobilenet_v2": "3.312",
        "resnet18": "3.453",
        "resnet34": "3.519",
        "resnet50": "3.320",
        "vgg11_bn": "0.0",
        "vgg13_bn": "4.781",
        "vgg16_bn": "4.631",
        "vgg19_bn": "4.219"
    },
    {
        "Metric": "L-Infinity",
        "Target": "vgg13_bn",
        "densenet121": "3.552",
        "densenet161": "3.513",
        "densenet169": "3.818",
        "googlenet": "3.565",
        "inception_v3": "3.484",
        "mobilenet_v2": "3.504",
        "resnet18": "3.476",
        "resnet34": "3.403",
        "resnet50": "3.383",
        "vgg11_bn": "4.781",
        "vgg13_bn": "0.0",
        "vgg16_bn": "2.687",
        "vgg19_bn": "4.085"
    },
    {
        "Metric": "L-Infinity",
        "Target": "vgg16_bn",
        "densenet121": "3.837",
        "densenet161": "4.184",
        "densenet169": "4.733",
        "googlenet": "3.946",
        "inception_v3": "3.705",
        "mobilenet_v2": "4.030",
        "resnet18": "3.766",
        "resnet34": "3.243",
        "resnet50": "3.613",
        "vgg11_bn": "4.631",
        "vgg13_bn": "2.687",
        "vgg16_bn": "0.0",
        "vgg19_bn": "4.296"
    },
    {
        "Metric": "L-Infinity",
        "Target": "vgg19_bn",
        "densenet121": "5.815",
        "densenet161": "5.868",
        "densenet169": "5.567",
        "googlenet": "5.478",
        "inception_v3": "5.038",
        "mobilenet_v2": "5.286",
        "resnet18": "5.601",
        "resnet34": "5.312",
        "resnet50": "4.863",
        "vgg11_bn": "4.219",
        "vgg13_bn": "4.085",
        "vgg16_bn": "4.296",
        "vgg19_bn": "0.0"
    },
    {
        "Metric": "Cosine",
        "Target": "densenet121",
        "densenet121": "0.0",
        "densenet161": "0.141",
        "densenet169": "0.141",
        "googlenet": "0.262",
        "inception_v3": "0.229",
        "mobilenet_v2": "0.201",
        "resnet18": "0.180",
        "resnet34": "0.177",
        "resnet50": "0.145",
        "vgg11_bn": "0.285",
        "vgg13_bn": "0.267",
        "vgg16_bn": "0.283",
        "vgg19_bn": "0.335"
    },
    {
        "Metric": "Cosine",
        "Target": "densenet161",
        "densenet121": "0.141",
        "densenet161": "0.0",
        "densenet169": "0.146",
        "googlenet": "0.290",
        "inception_v3": "0.232",
        "mobilenet_v2": "0.211",
        "resnet18": "0.181",
        "resnet34": "0.172",
        "resnet50": "0.161",
        "vgg11_bn": "0.286",
        "vgg13_bn": "0.278",
        "vgg16_bn": "0.288",
        "vgg19_bn": "0.339"
    },
    {
        "Metric": "Cosine",
        "Target": "densenet169",
        "densenet121": "0.141",
        "densenet161": "0.146",
        "densenet169": "0.0",
        "googlenet": "0.289",
        "inception_v3": "0.245",
        "mobilenet_v2": "0.204",
        "resnet18": "0.191",
        "resnet34": "0.183",
        "resnet50": "0.144",
        "vgg11_bn": "0.309",
        "vgg13_bn": "0.290",
        "vgg16_bn": "0.297",
        "vgg19_bn": "0.343"
    },
    {
        "Metric": "Cosine",
        "Target": "googlenet",
        "densenet121": "0.262",
        "densenet161": "0.290",
        "densenet169": "0.289",
        "googlenet": "0.0",
        "inception_v3": "0.236",
        "mobilenet_v2": "0.248",
        "resnet18": "0.319",
        "resnet34": "0.330",
        "resnet50": "0.246",
        "vgg11_bn": "0.337",
        "vgg13_bn": "0.292",
        "vgg16_bn": "0.339",
        "vgg19_bn": "0.358"
    },
    {
        "Metric": "Cosine",
        "Target": "inception_v3",
        "densenet121": "0.229",
        "densenet161": "0.232",
        "densenet169": "0.245",
        "googlenet": "0.236",
        "inception_v3": "0.0",
        "mobilenet_v2": "0.192",
        "resnet18": "0.256",
        "resnet34": "0.265",
        "resnet50": "0.219",
        "vgg11_bn": "0.319",
        "vgg13_bn": "0.271",
        "vgg16_bn": "0.304",
        "vgg19_bn": "0.328"
    },
    {
        "Metric": "Cosine",
        "Target": "mobilenet_v2",
        "densenet121": "0.201",
        "densenet161": "0.211",
        "densenet169": "0.204",
        "googlenet": "0.248",
        "inception_v3": "0.192",
        "mobilenet_v2": "0.0",
        "resnet18": "0.214",
        "resnet34": "0.218",
        "resnet50": "0.182",
        "vgg11_bn": "0.288",
        "vgg13_bn": "0.258",
        "vgg16_bn": "0.263",
        "vgg19_bn": "0.303"
    },
    {
        "Metric": "Cosine",
        "Target": "resnet18",
        "densenet121": "0.180",
        "densenet161": "0.181",
        "densenet169": "0.191",
        "googlenet": "0.319",
        "inception_v3": "0.256",
        "mobilenet_v2": "0.214",
        "resnet18": "0.0",
        "resnet34": "0.155",
        "resnet50": "0.166",
        "vgg11_bn": "0.278",
        "vgg13_bn": "0.266",
        "vgg16_bn": "0.277",
        "vgg19_bn": "0.326"
    },
    {
        "Metric": "Cosine",
        "Target": "resnet34",
        "densenet121": "0.177",
        "densenet161": "0.172",
        "densenet169": "0.183",
        "googlenet": "0.330",
        "inception_v3": "0.265",
        "mobilenet_v2": "0.218",
        "resnet18": "0.155",
        "resnet34": "0.0",
        "resnet50": "0.170",
        "vgg11_bn": "0.281",
        "vgg13_bn": "0.281",
        "vgg16_bn": "0.274",
        "vgg19_bn": "0.330"
    },
    {
        "Metric": "Cosine",
        "Target": "resnet50",
        "densenet121": "0.145",
        "densenet161": "0.161",
        "densenet169": "0.144",
        "googlenet": "0.246",
        "inception_v3": "0.219",
        "mobilenet_v2": "0.182",
        "resnet18": "0.166",
        "resnet34": "0.170",
        "resnet50": "0.0",
        "vgg11_bn": "0.273",
        "vgg13_bn": "0.243",
        "vgg16_bn": "0.261",
        "vgg19_bn": "0.305"
    },
    {
        "Metric": "Cosine",
        "Target": "vgg11_bn",
        "densenet121": "0.285",
        "densenet161": "0.286",
        "densenet169": "0.309",
        "googlenet": "0.337",
        "inception_v3": "0.319",
        "mobilenet_v2": "0.288",
        "resnet18": "0.278",
        "resnet34": "0.281",
        "resnet50": "0.273",
        "vgg11_bn": "0.0",
        "vgg13_bn": "0.160",
        "vgg16_bn": "0.180",
        "vgg19_bn": "0.238"
    },
    {
        "Metric": "Cosine",
        "Target": "vgg13_bn",
        "densenet121": "0.267",
        "densenet161": "0.278",
        "densenet169": "0.290",
        "googlenet": "0.292",
        "inception_v3": "0.271",
        "mobilenet_v2": "0.258",
        "resnet18": "0.266",
        "resnet34": "0.281",
        "resnet50": "0.243",
        "vgg11_bn": "0.160",
        "vgg13_bn": "0.0",
        "vgg16_bn": "0.130",
        "vgg19_bn": "0.177"
    },
    {
        "Metric": "Cosine",
        "Target": "vgg16_bn",
        "densenet121": "0.283",
        "densenet161": "0.288",
        "densenet169": "0.297",
        "googlenet": "0.339",
        "inception_v3": "0.304",
        "mobilenet_v2": "0.263",
        "resnet18": "0.277",
        "resnet34": "0.274",
        "resnet50": "0.261",
        "vgg11_bn": "0.180",
        "vgg13_bn": "0.130",
        "vgg16_bn": "0.0",
        "vgg19_bn": "0.162"
    },
    {
        "Metric": "Cosine",
        "Target": "vgg19_bn",
        "densenet121": "0.335",
        "densenet161": "0.339",
        "densenet169": "0.343",
        "googlenet": "0.358",
        "inception_v3": "0.328",
        "mobilenet_v2": "0.303",
        "resnet18": "0.326",
        "resnet34": "0.330",
        "resnet50": "0.305",
        "vgg11_bn": "0.238",
        "vgg13_bn": "0.177",
        "vgg16_bn": "0.162",
        "vgg19_bn": "0.0"
    }
]

# %%
dists_df = pd.DataFrame.from_dict(dists)

for column in dists_df.columns.to_list():
    if column == "Metric" or column == "Target":
        dists_df[column] = dists_df[column].astype(str)
    else:
        dists_df[column] = dists_df[column].astype(float)

# %%
cosine_dists = dists_df[dists_df["Metric"] == "Cosine"].drop(columns=["Metric"]).set_index("Target")
l_inf_dists = dists_df[dists_df["Metric"] == "L-Infinity"].drop(columns=["Metric"]).set_index("Target")

# %%
sns.set_style("white")
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

hm = sns.heatmap(data=cosine_dists, cmap="viridis_r", linewidths=0.25)
hm.set_title("Pairwise Distances with Zest Cosine - N = 128")
plt.savefig('cos_dists.png', bbox_inches="tight")
plt.tight_layout()
plt.show()
